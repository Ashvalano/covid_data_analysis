# %%
import pandas as pd
import matplotlib.pyplot as plt

import random
from tabulate import tabulate
from matplotlib.dates import WeekdayLocator, DateFormatter

# %% [markdown]
# ### Read dataset

# %%
covidData = pd.read_csv('Case_Information.csv')

covidData.head()
# covidData.info()
# covidData.shape

# print(covidData.columns)
# Out:
#    case_id   age age_group     sex date_announced date_recovered  \
# 0  C404174  38.0  35 to 39  Female     2020-01-30            NaN
# 1  C462688  44.0  40 to 44    Male     2020-02-03            NaN
# 2  C387710  60.0  60 to 64  Female     2020-02-05     2020-01-31
# 3  C377460  48.0  45 to 49    Male     2020-03-06            NaN
# 4  C498051  62.0  60 to 64    Male     2020-03-06            NaN
#
#   date_of_death     status date_announced_as_removed             province  \
# 0           NaN  Recovered                2020-02-07      Negros Oriental
# 1    2020-02-01       Died                2020-02-02      Negros Oriental
# 2           NaN  Recovered                2020-02-05                Bohol
# 3           NaN  Recovered                2020-03-27  Metropolitan Manila
# 4    2020-03-11       Died                2020-03-12                Rizal
#
#         muni_city health_status home_quarantined date_of_onset_of_symptoms  \
# 0  Dumaguete City     Recovered              NaN                2020-01-21
# 1  Dumaguete City          Died              NaN                2020-01-18
# 2         Panglao     Recovered               No                2020-01-21
# 3          Taguig     Recovered               No                2020-03-03
# 4          Cainta          Died               No                2020-02-25
#
#   pregnant                        region
# 0      NaN  Central Visayas (Region VII)
# 1      NaN  Central Visayas (Region VII)
# 2      NaN  Central Visayas (Region VII)
# 3      NaN           Metropolitan Manila
# 4      NaN      CALABARZON (Region IV-A)

# %% [markdown]
# ### Data Cleaning

# %%
nanCheck = covidData['date_announced'].isnull().sum()

print(nanCheck)

duplicate_ids = covidData.duplicated(subset='case_id', keep=False)

# Get the rows with duplicate IDs
duplicate_rows = covidData[duplicate_ids]

# Print the duplicate rows
print(duplicate_rows)
# Out:
# 0
#        case_id   age age_group   sex date_announced date_recovered  \
# 11993  C567672  35.0  35 to 39  Male     2020-05-15            NaN
# 11994  C567672  41.0  40 to 44  Male     2020-05-15            NaN
#
#       date_of_death          status date_announced_as_removed  \
# 11993           NaN  For validation                       NaN
# 11994           NaN  For validation                       NaN
#
#                   province muni_city health_status home_quarantined  \
# 11993  Metropolitan Manila    Taguig          Mild              NaN
# 11994                  NaN       NaN          Mild              NaN
#
#       date_of_onset_of_symptoms pregnant               region
# 11993                2020-04-24      NaN  Metropolitan Manila
# 11994                       NaN      NaN                  NaN

# %% [markdown]
# ### Most Cases by Gender

# %%
# Count the occurrences of each gender
casesByGender = covidData['sex'].value_counts()

# Create a bar chart
casesByGender.plot.bar()

# Set the labels and title
plt.xlabel('Gender')
plt.ylabel('Number of Cases')
plt.title('Number of Covid Cases by Gender')

plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--')
plt.tight_layout()

plt.show()

print(casesByGender)
# Out:
# sex
# Male      6521
# Female    5570
# Name: count, dtype: int64

# %% [markdown]
# ### Cases by Age Group

# %%
casesByAgeGroup = covidData['age_group'].value_counts()

#bar chart
casesByAgeGroup.plot.bar()


plt.xlabel('Gender')
plt.ylabel('Number of Cases')
plt.title('Number of Covid Cases by Age Group')

plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--')
plt.figure(figsize = (12,6))
plt.tight_layout()

plt.show()


# pie chart variation
# casesByAgeGroup.plot.pie()
# plt.axis('equal')
# plt.title('Number of Covid Cases by Age Group')
# plt.show()

print(casesByAgeGroup)
# Out:
# age_group
# 30 to 34    1510
# 25 to 29    1289
# 35 to 39    1061
# 45 to 49    1002
# 50 to 54     973
# 55 to 59     967
# 40 to 44     967
# 60 to 64     921
# 20 to 24     767
# 65 to 69     713
# 70 to 74     565
# 80+          321
# 75 to 79     287
# 15 to 19     282
# 10 to 14     169
# 0 to 4       154
# 5 to 9       122
# Name: count, dtype: int64

# %% [markdown]
# ### Distribution of Health Status by Age

# %%
age_health = covidData[['age_group', 'status']]
cross_tab = pd.crosstab(age_health['age_group'], age_health['status'])

cross_tab.plot(kind='bar', stacked=True)
plt.xlabel('Age')
plt.ylabel('Count')

plt.title('Distribution of Health Status by Age')
plt.legend(title='Health Status')

plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--')
plt.figure(figsize = (16,9))
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Tabular Format

# %%
print(tabulate(cross_tab, headers='keys', tablefmt='psql'))
# Out:
# +-------------+------------+--------+------------------+--------------------+-------------+
# | age_group   |   Admitted |   Died |   For validation |   Home quarantined |   Recovered |
# |-------------+------------+--------+------------------+--------------------+-------------|
# | 0 to 4      |         22 |      7 |              100 |                 11 |          14 |
# | 10 to 14    |          8 |      1 |              142 |                 11 |           7 |
# | 15 to 19    |         25 |      4 |              228 |                 15 |          10 |
# | 20 to 24    |         97 |      3 |              451 |                 90 |         126 |
# | 25 to 29    |        140 |      6 |              718 |                184 |         241 |
# | 30 to 34    |        185 |     11 |              745 |                230 |         339 |
# | 35 to 39    |        129 |     20 |              563 |                130 |         219 |
# | 40 to 44    |        128 |     30 |              506 |                114 |         189 |
# | 45 to 49    |        151 |     38 |              483 |                103 |         227 |
# | 5 to 9      |          5 |      1 |               98 |                  6 |          12 |
# | 50 to 54    |        137 |     60 |              441 |                101 |         234 |
# | 55 to 59    |        172 |     77 |              416 |                 82 |         220 |
# | 60 to 64    |        168 |    129 |              348 |                 68 |         208 |
# | 65 to 69    |        153 |    125 |              193 |                 50 |         192 |
# | 70 to 74    |        123 |    109 |              163 |                 44 |         126 |
# | 75 to 79    |         55 |     77 |               88 |                  9 |          58 |
# | 80+         |         72 |    108 |               90 |                 14 |          37 |
# +-------------+------------+--------+------------------+--------------------+-------------+

# %% [markdown]
# ### Covid cases distribution by date

# %%
covidData['date_announced'] = pd.to_datetime(covidData['date_announced'])
# covidData.info()

cases_by_date = covidData.groupby('date_announced').size()

cases_by_date.plot()
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.title('Distribution of COVID-19 Cases by Date')

plt.xticks(rotation=45)
plt.show()
print(cases_by_date)
# Out:
# date_announced
# 2020-01-30      1
# 2020-02-03      1
# 2020-02-05      1
# 2020-03-06      2
# 2020-03-07      1
#              ...
# 2020-05-11    292
# 2020-05-12    264
# 2020-05-13    268
# 2020-05-14    258
# 2020-05-15    215
# Length: 74, dtype: int64

# %% [markdown]
# #### Closer Inspection on sudden rise and fall

# %%
start_date = '2020-03-27'
end_date = '2020-04-10'
filtered_data = covidData.loc[(covidData['date_announced'] >= start_date) 
                              & (covidData['date_announced'] <= end_date)]


cases_by_date_filtered = filtered_data.groupby('date_announced').size()

# Plot the line chart
cases_by_date_filtered.plot(marker = 'o')

# Set the labels and title
plt.xlabel('Date Announced')
plt.ylabel('Number of Cases')
plt.title('Distribution of COVID-19 Cases by Date')

# plt.xticks(rotation=45)
plt.figure(figsize = (12,8))
plt.show()

# filtered_data.head(20)
# filtered_data.info()

# %% [markdown]
# ### by geographical location/region, by month, if pregnancy has any effect, date of symptoms vs date announced
